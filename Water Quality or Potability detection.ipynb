# %%
# Importing Numpy and Pandas
import numpy as np
import pandas as pd

import os

# %% [markdown]
# ### Data Analysis
# #### Reading CSV with Pandas

# %%
# Loading Data
df = pd.read_csv(os.path.join(os.getcwd(), "data/water_potability.csv"))
df.head(n=10)
# Out:
#           ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0        NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1   3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2   8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3   8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4   9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
# 5   5.584087  188.313324  28748.687739     7.544869  326.678363    280.467916
# 6  10.223862  248.071735  28749.716544     7.513408  393.663396    283.651634
# 7   8.635849  203.361523  13672.091764     4.563009  303.309771    474.607645
# 8        NaN  118.988579  14285.583854     7.804174  268.646941    389.375566
# 9  11.180284  227.231469  25484.508491     9.077200  404.041635    563.885481
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0
# 5        8.399735        54.917862   2.559708           0
# 6       13.789695        84.603556   2.672989           0
# 7       12.363817        62.798309   4.401425           0
# 8       12.706049        53.928846   3.595017           0
# 9       17.927806        71.976601   4.370562           0

# %% [markdown]
# The Data contains null values

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.describe().T
# Out:
#                   count          mean          std         min           25%  \
# ph               2785.0      7.080795     1.594320    0.000000      6.093092
# Hardness         3276.0    196.369496    32.879761   47.432000    176.850538
# Solids           3276.0  22014.092526  8768.570828  320.942611  15666.690297
# Chloramines      3276.0      7.122277     1.583085    0.352000      6.127421
# Sulfate          2495.0    333.775777    41.416840  129.000000    307.699498
# Conductivity     3276.0    426.205111    80.824064  181.483754    365.734414
# Organic_carbon   3276.0     14.284970     3.308162    2.200000     12.065801
# Trihalomethanes  3114.0     66.396293    16.175008    0.738000     55.844536
# Turbidity        3276.0      3.966786     0.780382    1.450000      3.439711
# Potability       3276.0      0.390110     0.487849    0.000000      0.000000
#
#                           50%           75%           max
# ph                   7.036752      8.062066     14.000000
# Hardness           196.967627    216.667456    323.124000
# Solids           20927.833607  27332.762127  61227.196008
# Chloramines          7.130299      8.114887     13.127000
# Sulfate            333.073546    359.950170    481.030642
# Conductivity       421.884968    481.792304    753.342620
# Organic_carbon      14.218338     16.557652     28.300000
# Trihalomethanes     66.622485     77.337473    124.000000
# Turbidity            3.955028      4.500320      6.739000
# Potability           0.000000      1.000000      1.000000

# %% [markdown]
# #### Primary Analysis - Finding Outliers

# %%
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### The solids are showing unreliable data

# %%
df.boxplot(['ph', 'Hardness', 'Solids', 'Organic_carbon', 'Turbidity'])
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %% [markdown]
# ### Missing Data

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %% [markdown]
# ### Handling Missing Data with Mean

# %%
# Replacing Missing Data with Mean

df['ph'] = df['ph'].fillna(df['ph'].mean())
df['Sulfate'] = df['Sulfate'].fillna(df['Sulfate'].mean())
df['Trihalomethanes'] = df['Trihalomethanes'].fillna(df['Trihalomethanes'].mean())

# Tried replacing with median values, poorer results achieved

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.hist(bins=10, figsize=(20,15), color = 'red')
# Out:
# array([[<AxesSubplot:title={'center':'ph'}>,
#         <AxesSubplot:title={'center':'Hardness'}>,
#         <AxesSubplot:title={'center':'Solids'}>],
#        [<AxesSubplot:title={'center':'Chloramines'}>,
#         <AxesSubplot:title={'center':'Sulfate'}>,
#         <AxesSubplot:title={'center':'Conductivity'}>],
#        [<AxesSubplot:title={'center':'Organic_carbon'}>,
#         <AxesSubplot:title={'center':'Trihalomethanes'}>,
#         <AxesSubplot:title={'center':'Turbidity'}>],
#        [<AxesSubplot:title={'center':'Potability'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.hist(column='ph', by='Potability', legend=True)
df.hist(column='Hardness', by='Potability' , legend=True)
df.hist(column='Solids', by='Potability',  legend=True)
df.hist(column='Chloramines', by='Potability',  legend=True)
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %% [markdown]
# ##### Solids showing same shape for both Potable and Non-Potable

# %%
df.hist(column='Sulfate', by='Potability',  legend=True)
df.hist(column='Conductivity', by='Potability',  legend=True)
df.hist(column='Organic_carbon', by='Potability',  legend=True)
df.hist(column='Trihalomethanes', by='Potability',  legend=True)
df.hist(column='Turbidity', by='Potability',  legend=True)
# Out:
# array([<AxesSubplot:title={'center':'0'}>,
#        <AxesSubplot:title={'center':'1'}>], dtype=object)

# %% [markdown]
# #### Importing Primary Classification Models from Sklearn

# %%
# classification tools
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier


# data preprocessors, metrics and evals
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler

# from sklearn.utils import resample

from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# importing seaborn for plotting conf matrix
import seaborn as sns

# %% [markdown]
# #### Preprocessing

# %%
# Preparing X, Y for all four dataframes


# Replaced Null with Mean

# Dropping column Solids as it seems unreliable

# X = df.drop(["Potability", "Solids"],axis=1)

X = df.drop(["Potability"],axis=1)
Y = df["Potability"]

print(X)
print(Y)

# df = df.sample(frac = 1) # shuffling the rows

# from sklearn.preprocessing import MinMaxScaler
# # Scaling Values from 0 to 1

# # MinMaxScaler Object
# scaler = MinMaxScaler()
# scaler.fit(X)

# X = scaler.transform(X)

# X = pd.DataFrame(X)
# X

# Scaling X values
scaler = StandardScaler()


X = scaler.fit_transform(X)
print(X)

# train-test split 75 - 25
x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.25, random_state=42)
# x_train, x_test, y_train, y_test = train_test_split(X,Y,test_size=0.25,stratify=Y)
# y_train = pd.Series(y_train)
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 0     7.080795  204.890455  20791.318981     7.300212  368.516441
# 1     3.716080  129.422921  18630.057858     6.635246  333.775777
# 2     8.099124  224.236259  19909.541732     9.275884  333.775777
# 3     8.316766  214.373394  22018.417441     8.059332  356.886136
# 4     9.092223  181.101509  17978.986339     6.546600  310.135738
# ...        ...         ...           ...          ...         ...
# 3271  4.668102  193.681735  47580.991603     7.166639  359.948574
# 3272  7.808856  193.553212  17329.802160     8.061362  333.775777
# 3273  9.419510  175.762646  33155.578218     7.350233  333.775777
# 3274  5.126763  230.603758  11983.869376     6.303357  333.775777
# 3275  7.874671  195.102299  17404.177061     7.509306  333.775777
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity
# 0       564.308654       10.379783        86.990970   2.963135
# 1       592.885359       15.180013        56.329076   4.500656
# 2       418.606213       16.868637        66.420093   3.055934
# 3       363.266516       18.436524       100.341674   4.628771
# 4       398.410813       11.558279        31.997993   4.075075
# ...            ...             ...              ...        ...
# 3271    526.424171       13.894419        66.687695   4.435821
# 3272    392.449580       19.903225        66.396293   2.798243
# 3273    432.044783       11.039070        69.845400   3.298875
# 3274    402.883113       11.168946        77.488213   4.708658
# 3275    327.459760       16.140368        78.698446   2.309149
#
# [3276 rows x 9 columns]
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3271    1
# 3272    1
# 3273    1
# 3274    1
# 3275    1
# Name: Potability, Length: 3276, dtype: int64
# [[-6.04313345e-16  2.59194711e-01 -1.39470871e-01 ... -1.18065057e+00
#    1.30614943e+00 -1.28629758e+00]
#  [-2.28933938e+00 -2.03641367e+00 -3.85986650e-01 ...  2.70597240e-01
#   -6.38479983e-01  6.84217891e-01]
#  [ 6.92867789e-01  8.47664833e-01 -2.40047337e-01 ...  7.81116857e-01
#    1.50940884e-03 -1.16736546e+00]
#  ...
#  [ 1.59125368e+00 -6.26829230e-01  1.27080989e+00 ... -9.81329234e-01
#    2.18748247e-01 -8.56006782e-01]
#  [-1.32951593e+00  1.04135450e+00 -1.14405809e+00 ... -9.42063817e-01
#    7.03468419e-01  9.50797383e-01]
#  [ 5.40150905e-01 -3.85462310e-02 -5.25811937e-01 ...  5.60940070e-01
#    7.80223466e-01 -2.12445866e+00]]

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# #### Replace By Mean, Median and Dropped Values

# %%
import matplotlib.pyplot as plt

# training 
lr = LogisticRegression(max_iter=200,random_state=42, n_jobs=20)
lr.fit(x_train,y_train)
logistic_score = lr.score(x_train,y_train)

print("Training score for mean : ", logistic_score)

# Making Prediction
pred_lr = lr.predict(x_test)
lg = accuracy_score(y_test, pred_lr)
print("Accuracy score for mean: ", lg)

# classification report for Log Reg
print(classification_report(y_test,pred_lr,zero_division=True))

# confusion Maxtrix
conf_mat_lr = confusion_matrix(y_test, pred_lr)
sns.heatmap(conf_mat_lr/np.sum(conf_mat_lr), annot = True, fmt=  '0.2%', cmap = 'Reds')
# Out:
# Training score for mean :  0.6056166056166056
# Accuracy score for mean:  0.6227106227106227
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77       510
#            1       1.00      0.00      0.00       309
#
#     accuracy                           0.62       819
#    macro avg       0.81      0.50      0.38       819
# weighted avg       0.77      0.62      0.48       819
# <AxesSubplot:>

# %% [markdown]
# #### Training with Decision Tree

# %%
# Model object
dt = DecisionTreeClassifier(max_depth=9, random_state=42)

# Training Model
dt.fit(x_train,y_train)
dt_score = dt.score(x_train,y_train)
print("Training Score : ", dt_score)
# Making Prediction
pred_dt = dt.predict(x_test)

# Calculating Accuracy Score
dt_test_score = accuracy_score(y_test, pred_dt)
print("Accuracy score : ",dt_test_score)

# Classification Report
print(classification_report(y_test,pred_dt))

# confusion Maxtrix
conf_mat_dt = confusion_matrix(y_test, pred_dt)
sns.heatmap(conf_mat_dt/np.sum(conf_mat_dt), annot = True, fmt=  '0.2%', cmap = 'Greens')
# Out:
# Training Score :  0.7350427350427351
# Accuracy score :  0.645909645909646
#               precision    recall  f1-score   support
#
#            0       0.66      0.87      0.75       510
#            1       0.56      0.27      0.37       309
#
#     accuracy                           0.65       819
#    macro avg       0.61      0.57      0.56       819
# weighted avg       0.63      0.65      0.61       819
# <AxesSubplot:>

# %% [markdown]
# #### Training with Random Forest Classifier

# %%
# training 
rfc = RandomForestClassifier(n_estimators=1000,min_samples_leaf=9, random_state=23)
rfc.fit(x_train,y_train)
rfc_score = rfc.score(x_train,y_train)
print("Training Score : ",rfc_score)


prediction_rfc = rfc.predict(x_test)
rfc_test_score = accuracy_score(y_test, prediction_rfc)
print("Accuracy score : ",rfc_test_score)


# Classification report
print(classification_report(y_test,prediction_rfc, zero_division=True))

# confusion Maxtrix
conf_mat_rfc = confusion_matrix(y_test, prediction_rfc)
sns.heatmap(conf_mat_rfc/np.sum(conf_mat_rfc), annot = True, fmt=  '0.2%', cmap = 'Blues')
# Out:
# Training Score :  0.8660968660968661
# Accuracy score :  0.6825396825396826
#               precision    recall  f1-score   support
#
#            0       0.68      0.93      0.78       510
#            1       0.70      0.28      0.40       309
#
#     accuracy                           0.68       819
#    macro avg       0.69      0.60      0.59       819
# weighted avg       0.69      0.68      0.64       819
# <AxesSubplot:>

# %% [markdown]
# #### Training with Linear SVC

# %%
# training 
lsvc = LinearSVC(max_iter=100000)
lsvc.fit(x_train,y_train)
lsvc_score = lsvc.score(x_train,y_train)

print("Training Score : ",lsvc_score)

prediction_lsvc = lsvc.predict(x_test)
lsvc_test_score = accuracy_score(y_test, prediction_lsvc)
print("Accuracy score : ",lsvc_test_score)


# Classification report
print(classification_report(y_test,prediction_lsvc, zero_division=True))

# confusion Maxtrix
conf_mat_lsvc = confusion_matrix(y_test,prediction_lsvc)
sns.heatmap(conf_mat_lsvc/np.sum(conf_mat_lsvc), annot = True, fmt=  '0.2%', cmap = 'Greys')
# Out:
# Training Score :  0.6056166056166056
# Accuracy score :  0.6227106227106227
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77       510
#            1       1.00      0.00      0.00       309
#
#     accuracy                           0.62       819
#    macro avg       0.81      0.50      0.38       819
# weighted avg       0.77      0.62      0.48       819
# <AxesSubplot:>

# %% [markdown]
# ### K - Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# Model object - 9 neighbors
knn = KNeighborsClassifier(n_neighbors=42, leaf_size=1800)

# Training Model
knn.fit(x_train, y_train)

# Training score
knn_score = knn.score(x_train,y_train)
print("Training Score : ",knn_score)

# Making Prediction
predict_knn = knn.predict(x_test)

knn_test_score = accuracy_score(y_test, predict_knn)
print("Accuracy score : ",knn_test_score)


# Classification report
print(classification_report(y_test,predict_knn, zero_division=True))

# confusion Maxtrix
conf_mat_knn = confusion_matrix(y_test,predict_knn)
sns.heatmap(conf_mat_knn/np.sum(conf_mat_knn), annot = True, fmt=  '0.2%', cmap = 'BuGn')
# Out:
# Training Score :  0.6585266585266585
# Accuracy score :  0.6642246642246642
#               precision    recall  f1-score   support
#
#            0       0.66      0.96      0.78       510
#            1       0.74      0.17      0.28       309
#
#     accuracy                           0.66       819
#    macro avg       0.70      0.57      0.53       819
# weighted avg       0.69      0.66      0.59       819
# <AxesSubplot:>

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
# Model object 
gnb = GaussianNB()
# Training Model
gnb.fit(x_train, y_train)

# Training score
gnb_score = gnb.score(x_train,y_train)
print("Training Score : ",gnb_score)

# Making Prediction
predict_gnb = gnb.predict(x_test)

gnb_test_score = accuracy_score(y_test, predict_gnb)
print("Accuracy score : ",gnb_test_score)


# Classification report
print(classification_report(y_test,predict_gnb, zero_division=True))

# confusion Maxtrix
conf_mat_gnb = confusion_matrix(y_test,predict_gnb)
sns.heatmap(conf_mat_gnb/np.sum(conf_mat_gnb), annot = True, fmt=  '0.2%', cmap = 'PuBu')
# Out:
# Training Score :  0.628001628001628
# Accuracy score :  0.6361416361416361
#               precision    recall  f1-score   support
#
#            0       0.65      0.89      0.75       510
#            1       0.55      0.21      0.31       309
#
#     accuracy                           0.64       819
#    macro avg       0.60      0.55      0.53       819
# weighted avg       0.61      0.64      0.58       819
# <AxesSubplot:>

# %% [markdown]
# ### Gradient Boost

# %%
# Model object 
gbm=GradientBoostingClassifier(random_state=42)

# Training Model
gbm.fit(x_train, y_train)

# Training score
gbm_score = gbm.score(x_train,y_train)
print("Training Score : ",gbm_score)

# Making Prediction
predict_gbm = gbm.predict(x_test)

gbm_test_score = accuracy_score(y_test, predict_gbm)
print("Accuracy score : ",gbm_test_score)


# Classification report
print(classification_report(y_test,predict_gbm, zero_division=True))

# confusion Maxtrix
conf_mat_gbm = confusion_matrix(y_test,predict_gbm)
sns.heatmap(conf_mat_gbm/np.sum(conf_mat_gbm), annot = True, fmt=  '0.2%', cmap = 'BuGn')
# Out:
# Training Score :  0.7407407407407407
# Accuracy score :  0.6605616605616605
#               precision    recall  f1-score   support
#
#            0       0.66      0.92      0.77       510
#            1       0.63      0.24      0.34       309
#
#     accuracy                           0.66       819
#    macro avg       0.65      0.58      0.56       819
# weighted avg       0.65      0.66      0.61       819
# <AxesSubplot:>

# %% [markdown]
# ### Gradient Boost (tuned params)

# %%
# Parameters

gbm_params = {
    "n_estimators" : [5, 10, 25, 50,75, 100, 250, 500],
    "max_depth":[1,3,5,7,9],
    "learning_rate":[0.01,0.1,1,2]
}

# Model Object
gbm = GradientBoostingClassifier(random_state=42)
gbm_cv = GridSearchCV(gbm, gbm_params, cv=10, n_jobs=-1, verbose=2)

# Training

gbm_cv.fit(x_train,y_train)

gbm_cv.best_params_
# Out:
# Fitting 10 folds for each of 160 candidates, totalling 1600 fits
# [CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.2s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.4s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   1.0s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   1.0s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   1.0s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.0s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.1s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   2.7s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   2.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   5.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   6.5s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.9s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.9s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.3s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.3s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   2.0s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.8s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.0s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.5s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   9.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   8.2s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.7s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.5s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.9s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   2.3s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   2.8s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   3.7s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   3.8s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   3.0s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   8.0s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   8.2s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  14.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  16.1s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  15.7s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.7s[CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   0.8s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.0s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.4s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.7s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   1.0s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   1.0s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.0s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   3.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   2.7s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   4.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   6.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   5.8s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.3s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.2s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   1.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   1.8s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.4s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.2s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   7.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   8.7s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.2s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.5s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   2.0s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   1.8s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   2.9s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   3.2s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   2.5s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   8.5s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   8.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  14.2s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  16.5s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  16.0s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.7s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.5s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=75; total time=   3.5s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=75; total time=   3.0s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=75; total time=   2.7s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=   4.1s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=   4.1s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=250; total time=   9.7s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=250; total time=   9.8s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=250; total time=   9.5s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time=  20.0s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time=  20.1s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END .....learning_rate=0.1, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.0s[CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.0s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.0s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.0s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=10; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   3.1s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   4.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   6.2s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   6.5s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.9s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   1.0s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.4s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.5s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   1.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   2.0s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   1.8s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.1s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.0s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   8.0s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   8.6s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   8.7s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=25; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.5s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.5s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   2.2s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   1.8s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   3.2s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   3.8s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   2.8s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   7.5s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   8.8s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   6.9s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  14.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  15.9s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.1s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.1s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.0s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   0.9s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.1s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.6s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.3s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.2s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=75; total time=   3.9s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=75; total time=   3.1s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=75; total time=   2.8s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=   4.0s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=   4.1s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=250; total time=   9.8s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=250; total time=  10.7s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time=  18.6s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time=  19.9s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time=  19.8s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=250; total time=   1.1s[CV] END ....learning_rate=0.01, max_depth=1, n_estimators=5; total time=   0.0s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=1, n_estimators=75; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.3s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   1.0s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=250; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.2s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   1.9s
# [CV] END ..learning_rate=0.01, max_depth=1, n_estimators=500; total time=   2.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=25; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=50; total time=   0.6s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   0.9s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   1.0s
# [CV] END ...learning_rate=0.01, max_depth=3, n_estimators=75; total time=   0.9s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=100; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   2.6s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   2.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=250; total time=   2.3s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   4.5s
# [CV] END ..learning_rate=0.01, max_depth=3, n_estimators=500; total time=   7.2s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.01, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=25; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=50; total time=   0.8s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.2s
# [CV] END ...learning_rate=0.01, max_depth=5, n_estimators=75; total time=   1.3s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   1.7s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   1.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=100; total time=   1.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   3.9s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=250; total time=   4.1s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   7.8s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   9.0s
# [CV] END ..learning_rate=0.01, max_depth=5, n_estimators=500; total time=   8.9s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.2s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.3s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=50; total time=   1.4s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   2.2s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   2.4s
# [CV] END ...learning_rate=0.01, max_depth=7, n_estimators=75; total time=   2.7s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   3.6s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=100; total time=   2.4s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   7.8s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   9.1s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=250; total time=   6.6s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  15.5s
# [CV] END ..learning_rate=0.01, max_depth=7, n_estimators=500; total time=  15.7s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.01, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.3s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=10; total time=   0.5s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.2s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.4s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.1s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.2s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=25; total time=   1.4s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.2s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.7s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=50; total time=   2.5s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=75; total time=   4.1s
# [CV] END ...learning_rate=0.01, max_depth=9, n_estimators=75; total time=   3.1s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=   3.9s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=   4.4s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=100; total time=   4.0s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=250; total time=  10.2s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=250; total time=  10.2s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time=  18.7s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time=  19.9s
# [CV] END ..learning_rate=0.01, max_depth=9, n_estimators=500; total time=  20.7s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=500; total time=   3.9s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=500; total time=   4.2s
# [CV] END .....learning_rate=0.1, max_depth=3, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.0s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=10; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=25; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=50; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=50; total time=   0.3s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=50; total time=   0.3s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=75; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=75; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=75; total time=   0.3s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=75; total time=   0.5s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=75; total time=   0.3s
# [CV] END ....learning_rate=0.1, max_depth=1, n_estimators=75; total time=   0.3s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.4s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.5s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=250; total time=   1.1s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=250; total time=   1.1s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=250; total time=   1.2s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=250; total time=   1.3s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=500; total time=   3.4s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=500; total time=   3.9s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=500; total time=   3.9s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=25; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=25; total time=   0.6s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   1.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   1.5s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.8s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=75; total time=   1.6s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=75; total time=   1.6s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=250; total time=   2.8s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=250; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=250; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   5.3s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   5.1s
# [CV] END .....learning_rate=0.1, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=25; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=25; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=25; total time=   0.5s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=25; total time=   0.5s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.9s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   1.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.9s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=75; total time=   1.3s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=75; total time=   1.9s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   2.7s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   3.1s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   2.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=250; total time=   5.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=250; total time=   4.4s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=  10.5s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=   9.7s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=  14.0s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   2.8s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   1.4s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=75; total time=   2.0s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=75; total time=   2.2s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=75; total time=   2.0s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   2.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=250; total time=   6.6s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=250; total time=   7.1s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=250; total time=   7.5s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=500; total time=  15.1s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=500; total time=  15.6s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   0.9s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   1.1s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   1.1s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   1.1s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=250; total time=   1.4s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=500; total time=   3.6s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=500; total time=   3.8s
# [CV] END ...learning_rate=0.1, max_depth=1, n_estimators=500; total time=   4.1s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=25; total time=   0.6s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=25; total time=   0.7s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   0.9s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=50; total time=   1.2s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=75; total time=   1.6s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=75; total time=   0.9s
# [CV] END ....learning_rate=0.1, max_depth=3, n_estimators=75; total time=   1.1s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.6s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.4s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=100; total time=   1.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=250; total time=   2.6s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=250; total time=   2.5s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   5.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   5.2s
# [CV] END ...learning_rate=0.1, max_depth=3, n_estimators=500; total time=   5.2s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=25; total time=   0.5s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   0.9s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=50; total time=   1.1s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=75; total time=   1.3s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=75; total time=   1.5s
# [CV] END ....learning_rate=0.1, max_depth=5, n_estimators=75; total time=   2.2s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   2.9s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=100; total time=   2.1s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=250; total time=   5.4s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=250; total time=   4.4s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=250; total time=   4.3s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=  10.1s
# [CV] END ...learning_rate=0.1, max_depth=5, n_estimators=500; total time=  10.6s
# [CV] END .....learning_rate=0.1, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=7, n_estimators=5; total time=   0.2s
# [CV] END .....learning_rate=0.1, max_depth=7, n_estimators=5; total time=   0.1s
# [CV] END .....learning_rate=0.1, max_depth=7, n_estimators=5; total time=   0.2s
# [CV] END .....learning_rate=0.1, max_depth=7, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=10; total time=   0.5s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=25; total time=   1.1s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=25; total time=   1.3s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=25; total time=   1.3s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=25; total time=   1.3s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=25; total time=   1.7s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   2.9s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=50; total time=   1.3s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=75; total time=   2.2s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=75; total time=   2.2s
# [CV] END ....learning_rate=0.1, max_depth=7, n_estimators=75; total time=   2.1s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   2.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=100; total time=   2.8s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=250; total time=   6.9s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=250; total time=   7.2s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=250; total time=   7.2s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=500; total time=  13.9s
# [CV] END ...learning_rate=0.1, max_depth=7, n_estimators=500; total time=  16.1s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.3s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.3s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END .....learning_rate=0.1, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=10; total time=   0.4s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   0.9s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   1.0s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   1.0s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   1.1s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=25; total time=   1.2s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=50; total time=   2.1s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=50; total time=   2.1s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=75; total time=   3.3s
# [CV] END ....learning_rate=0.1, max_depth=9, n_estimators=75; total time=   3.8s
# ...
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   1.0s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   0.7s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   1.0s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   1.3s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   1.0s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=50; total time=   2.4s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=50; total time=   2.5s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=50; total time=   1.8s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   2.9s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   3.0s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   3.9s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   4.3s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   4.6s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=  10.6s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=   9.3s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  17.0s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  21.5s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  19.2s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.5s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   2.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   2.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   3.5s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   5.0s
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=100; total time=   3.4s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=100; total time=   3.0s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=100; total time=   2.6s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=250; total time=   7.4s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=250; total time=   7.4s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=500; total time=  14.8s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=500; total time=  13.0s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=500; total time=  14.6s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=50; total time=   2.3s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=50; total time=   2.1s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   2.7s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   3.4s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   4.1s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   3.8s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   3.3s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=   9.3s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=  11.3s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=  11.3s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  19.5s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  17.4s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.5s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.4s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.5s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.3s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.5s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.4s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.4s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.4s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.5s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.7s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.4s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.4s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.4s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   2.8s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   2.9s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   2.2s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   4.3s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   4.0s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   3.4s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   6.3s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   5.6s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  12.9s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  12.6s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  13.3s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  28.9s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  34.6s
#
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   4.6s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   5.0s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   5.8s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  13.6s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  14.8s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  13.5s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  28.7s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  34.2s
#
# [CV] END .....learning_rate=2, max_depth=1, n_estimators=500; total time=   4.6s
# [CV] END .....learning_rate=2, max_depth=1, n_estimators=500; total time=   3.7s
# [CV] END ......learning_rate=2, max_depth=3, n_estimators=25; total time=   0.4s
# [CV] END ......learning_rate=2, max_depth=3, n_estimators=25; total time=   0.8s
# [CV] END ......learning_rate=2, max_depth=3, n_estimators=50; total time=   0.8s
# [CV] END ......learning_rate=2, max_depth=3, n_estimators=50; total time=   1.1s
# [CV] END ......learning_rate=2, max_depth=3, n_estimators=50; total time=   1.5s
# [CV] END ......learning_rate=2, max_depth=3, n_estimators=75; total time=   2.1s
# [CV] END ......learning_rate=2, max_depth=3, n_estimators=75; total time=   1.9s
# [CV] END .....learning_rate=2, max_depth=3, n_estimators=100; total time=   2.7s
# [CV] END .....learning_rate=2, max_depth=3, n_estimators=100; total time=   2.9s
# [CV] END .....learning_rate=2, max_depth=3, n_estimators=100; total time=   2.2s
# [CV] END .....learning_rate=2, max_depth=3, n_estimators=250; total time=   4.2s
# [CV] END .....learning_rate=2, max_depth=3, n_estimators=250; total time=   4.6s
# [CV] END .....learning_rate=2, max_depth=3, n_estimators=250; total time=   5.6s
# [CV] END .....learning_rate=2, max_depth=3, n_estimators=500; total time=   7.7s
# [CV] END .....learning_rate=2, max_depth=3, n_estimators=500; total time=   8.1s
# [CV] END .......learning_rate=2, max_depth=5, n_estimators=5; total time=   0.2s
# [CV] END .......learning_rate=2, max_depth=5, n_estimators=5; total time=   0.2s
# [CV] END .......learning_rate=2, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END .......learning_rate=2, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END .......learning_rate=2, max_depth=5, n_estimators=5; total time=   0.1s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=10; total time=   0.3s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=10; total time=   0.3s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=10; total time=   0.2s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=10; total time=   0.3s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=25; total time=   1.1s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=25; total time=   0.7s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=25; total time=   0.8s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=25; total time=   0.5s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=50; total time=   1.4s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=50; total time=   1.6s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=50; total time=   1.3s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=75; total time=   1.6s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=75; total time=   1.8s
# [CV] END ......learning_rate=2, max_depth=5, n_estimators=75; total time=   2.1s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=100; total time=   3.7s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=100; total time=   2.4s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=250; total time=   7.0s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=250; total time=   7.8s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=250; total time=   7.0s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=500; total time=  14.2s
# [CV] END .....learning_rate=2, max_depth=5, n_estimators=500; total time=  13.4s
# [CV] END .......learning_rate=2, max_depth=7, n_estimators=5; total time=   0.2s
# [CV] END .......learning_rate=2, max_depth=7, n_estimators=5; total time=   0.3s
# [CV] END .......learning_rate=2, max_depth=7, n_estimators=5; total time=   0.2s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=10; total time=   0.3s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=10; total time=   0.4s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=10; total time=   0.4s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=10; total time=   0.5s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=10; total time=   0.4s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   0.9s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   1.0s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   1.1s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   1.1s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=25; total time=   1.0s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=50; total time=   3.1s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=50; total time=   1.9s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   3.1s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   3.1s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   2.7s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   4.1s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   4.4s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=   9.5s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=  11.0s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=  10.1s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  21.8s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  20.6s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.2s
# [CV] END .......learning_rate=2, max_depth=9, n_estimators=5; total time=   0.3s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.5s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.5s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=10; total time=   0.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.5s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.3s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=25; total time=   1.4s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   2.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   3.1s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   3.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   3.9s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   4.9s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   5.3s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   5.6s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   6.6s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  14.8s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  14.2s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  24.0s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  31.2s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  24.8s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   2.8s
# [CV] END ......learning_rate=2, max_depth=7, n_estimators=75; total time=   3.3s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   4.1s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=100; total time=   4.1s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=   9.8s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=250; total time=  11.5s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  20.0s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  22.2s
# [CV] END .....learning_rate=2, max_depth=7, n_estimators=500; total time=  20.7s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   3.1s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=50; total time=   3.5s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   3.6s
# [CV] END ......learning_rate=2, max_depth=9, n_estimators=75; total time=   4.2s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   6.0s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   5.5s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=100; total time=   5.4s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  12.8s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=250; total time=  14.7s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  27.6s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  30.7s
# [CV] END .....learning_rate=2, max_depth=9, n_estimators=500; total time=  24.8s

# %%
# Tuned Model
gbm_tuned=GradientBoostingClassifier(random_state=42,learning_rate=0.1,max_depth=5,n_estimators=65)
# Train
gbm_tuned.fit(x_train,y_train)

# Training score
gbm_tuned_score = gbm_tuned.score(x_train,y_train)
print("Training Score : ",gbm_tuned_score)


gbm_tuned_pred = gbm_tuned.predict(x_test)


gbm_tuned_test_score = accuracy_score(y_test, gbm_tuned_pred)
print("Accuracy score : ",gbm_tuned_test_score)


# Classification report
print(classification_report(y_test, gbm_tuned_pred, zero_division=True))

# confusion Maxtrix
conf_mat_gbm_tuned = confusion_matrix(y_test, gbm_tuned_pred)
sns.heatmap(conf_mat_gbm_tuned/np.sum(conf_mat_gbm_tuned), annot = True, fmt=  '0.2%', cmap = 'BuGn')
# Out:
# Training Score :  0.803011803011803
# Accuracy score :  0.6752136752136753
#               precision    recall  f1-score   support
#
#            0       0.68      0.89      0.77       510
#            1       0.64      0.32      0.42       309
#
#     accuracy                           0.68       819
#    macro avg       0.66      0.60      0.60       819
# weighted avg       0.67      0.68      0.64       819
# <AxesSubplot:>

# %% [markdown]
# ### Artificial Neural Network
# #### Multi-Layer Perceptron

# %%
# Model
mlp=MLPClassifier(hidden_layer_sizes=90, max_iter=1600)
# Train
mlp.fit(x_train,y_train)

# Training score
mlp_score =mlp.score(x_train,y_train)
print("Training Score : ",mlp_score)


mlp_pred = mlp.predict(x_test)


mlp_test_score = accuracy_score(y_test, mlp_pred)
print("Accuracy score : ",mlp_test_score)


# Classification report
print(classification_report(y_test, mlp_pred, zero_division=True))

# confusion Maxtrix
conf_mat_mlp = confusion_matrix(y_test, mlp_pred)
sns.heatmap(conf_mat_mlp/np.sum(conf_mat_mlp), annot = True, fmt=  '0.2%', cmap = 'BuGn')
# Out:
# Training Score :  0.8351648351648352
# Accuracy score :  0.652014652014652
#               precision    recall  f1-score   support
#
#            0       0.70      0.76      0.73       510
#            1       0.54      0.48      0.51       309
#
#     accuracy                           0.65       819
#    macro avg       0.62      0.62      0.62       819
# weighted avg       0.64      0.65      0.65       819
# <AxesSubplot:>
